# %%
# Importing Libraries
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox

# %%
import scipy
from scipy import stats

# %%
#defining cross entropy loss for scoring
epsilon=0.00000001
def KL(x, y):
    x = np.asarray(x, dtype=np.float)
    y = np.asarray(y, dtype=np.float)

    return (-(np.sum(x * np.log2(y), 0)))

# %%
Patho1 = './Downloads/Original_IETR/balloons_cam03_6_original.png'

tempo1 = cv2.imread(Patho1)

bboxo1, labelo1, confo1 = cv.detect_common_objects(tempo1)

output_imageo1 = draw_bbox(tempo1, bboxo1, labelo1, confo1)

obj11=output_imageo1[bboxo1[0][1]:bboxo1[0][3],bboxo1[0][0]:bboxo1[0][2]].flatten()
mu11=np.mean(obj11)
obj11=obj11-mu11
pdfo1, binso1, po1=plt.hist(obj11, 256, density=True)
pdfo1=pdfo1+epsilon



    

#plt.imshow(output_imageo1)
#print(labelo1)

# %%
Patho2 = './Downloads/Original_IETR/BookArrival_cam09_58_original.png'

tempo2 = cv2.imread(Patho2)

objo2=[]

bboxo2, labelo2, confo2 = cv.detect_common_objects(tempo2)

output_imageo2 = draw_bbox(tempo2, bboxo2, labelo2, confo2)


for j in range (len(bboxo2)):
    
    
    opimgo2=output_imageo2[bboxo2[j][1]:bboxo2[j][3],bboxo2[j][0]:bboxo2[j][2]].flatten()
    muo2=np.mean(opimgo2)
    opimgo2=opimgo2-muo2
                
        
    xo2, binso2, po2=plt.hist(opimgo2, 256, density=True)
    xo2=xo2+epsilon
    objo2.append(xo2)

objo2=np.array(objo2)
print(objo2[1])


    

#plt.imshow(output_imageo1)
#print(labelo1)
# Out:
# [9.83758210e-05 5.44251350e-05 8.37255923e-05 1.06747380e-04
#  1.33954948e-04 1.65348295e-04 1.48605176e-04 5.86847302e-03
#  2.51156777e-04 3.03479022e-04 3.49522598e-04 5.31604011e-04
#  6.96942306e-04 1.52154089e-03 1.71199386e-03 4.89318637e-03
#  5.53570354e-03 1.40977157e-02 1.47297685e-02 3.01585521e-02
#  3.02924971e-02 4.47418083e-02 3.80717685e-02 4.17092110e-02
#  4.22805699e-02 2.70694468e-02 3.42417801e-02 2.23562589e-02
#  2.83858745e-02 2.22599860e-02 2.23102153e-02 2.37857027e-02
#  1.63705941e-02 1.92273887e-02 1.37042525e-02 1.34761275e-02
#  1.07281632e-02 1.11048833e-02 9.86379966e-03 8.39668391e-03
#  9.62311733e-03 8.04926420e-03 8.34854744e-03 7.27070919e-03
#  7.27280208e-03 7.41930437e-03 6.59470578e-03 6.96305439e-03
#  6.43355327e-03 6.24519319e-03 6.06939044e-03 5.66336982e-03
#  5.92916682e-03 5.43105905e-03 5.74499252e-03 4.91202238e-03
#  4.99364508e-03 5.24897764e-03 4.75924142e-03 4.72994096e-03
# ...

# %%
Patho3 = './Downloads/Original_IETR/Dancer_cam05_66_original.png'

tempo3 = cv2.imread(Patho3)

objo3=[]

bboxo3, labelo3, confo3 = cv.detect_common_objects(tempo3)

output_imageo3 = draw_bbox(tempo3, bboxo3, labelo3, confo3)


for k in range (len(bboxo3)):
    
    
    opimgo3=output_imageo3[bboxo3[k][1]:bboxo3[k][3],bboxo3[k][0]:bboxo3[k][2]].flatten()
    muo3=np.mean(opimgo3)
    opimgo3=opimgo3-muo3
                
        
    xo3, binso3, po3=plt.hist(opimgo3, 256, density=True)
    xo3=xo3+epsilon
    objo3.append(xo3)

objo3=np.array(objo3)
print(xo3)
# Out:
# [9.22338087e-06 1.84367617e-05 3.68635235e-05 1.67167053e-04
#  2.21131141e-04 3.33007909e-04 3.46169881e-04 4.43427859e-03
#  6.19938913e-04 7.96309347e-04 1.01874669e-03 1.35964178e-03
#  1.40439248e-03 2.00194604e-03 1.86111294e-03 2.14146295e-03
#  2.39022424e-03 1.85848054e-03 2.80745877e-03 1.76108194e-03
#  2.79034821e-03 2.59160242e-03 2.37969466e-03 3.24180387e-03
#  2.87195244e-03 2.88906300e-03 2.56659467e-03 3.11544893e-03
#  3.15230246e-03 2.89301159e-03 3.55242643e-03 3.27865739e-03
#  2.84299610e-03 2.72980313e-03 3.04963907e-03 3.36684261e-03
#  3.23127429e-03 3.29181937e-03 2.58633763e-03 3.18915598e-03
#  2.90748976e-03 3.00225597e-03 2.95882146e-03 3.02463132e-03
#  3.14045668e-03 2.85220948e-03 3.20231795e-03 2.48630664e-03
#  2.65214749e-03 2.67583904e-03 2.80219398e-03 2.72190595e-03
#  2.77323764e-03 3.01015315e-03 2.37837846e-03 3.25759824e-03
#  2.90748976e-03 3.47740318e-03 3.00488836e-03 3.52083769e-03
# ...

# %%
Patho4 = './Downloads/Original_IETR/GT_Fly_cam05_150_original.png'

tempo4 = cv2.imread(Patho4)

objo4=[]

bboxo4, labelo4, confo4 = cv.detect_common_objects(tempo4)

output_imageo4 = draw_bbox(tempo4, bboxo4, labelo4, confo4)


for l in range (len(bboxo4)):
    
    
    opimgo4=output_imageo4[bboxo4[l][1]:bboxo4[l][3],bboxo4[l][0]:bboxo4[l][2]].flatten()
    muo4=np.mean(opimgo4)
    opimgo4=opimgo4-muo4
                
        
    xo4, binso4, po4=plt.hist(opimgo4, 256, density=True)
    xo4=xo4+epsilon
    objo4.append(xo3)

objo4=np.array(objo4)
print(len(bboxo4))
# Out:
# 2

# %%
Patho5 = './Downloads/Original_IETR/kendo_cam03_10_original.png'

tempo5 = cv2.imread(Patho5)

objo5=[]

bboxo5, labelo5, confo5 = cv.detect_common_objects(tempo5)

output_imageo5 = draw_bbox(tempo5, bboxo5, labelo5, confo5)


for m in range (len(bboxo5)):
    
    
    opimgo5=output_imageo5[bboxo5[m][1]:bboxo5[m][3],bboxo5[m][0]:bboxo5[m][2]].flatten()
    muo5=np.mean(opimgo5)
    opimgo5=opimgo5-muo5
                
        
    xo5, binso5, po5=plt.hist(opimgo5, 256, density=True)
    xo5=xo5+epsilon
    objo5.append(xo5)

objo5=np.array(objo5)
print(len(bboxo5))
# Out:
# 7

# %%
Patho6 = './Downloads/Original_IETR/Lovebird1_cam06_80_original.png'

tempo6 = cv2.imread(Patho6)

objo6=[]

bboxo6, labelo6, confo6 = cv.detect_common_objects(tempo6)

output_imageo6 = draw_bbox(tempo6, bboxo6, labelo6, confo6)


for n in range (len(bboxo6)):
    
    
    opimgo6=output_imageo6[bboxo6[n][1]:bboxo6[n][3],bboxo6[n][0]:bboxo6[n][2]].flatten()
    muo6=np.mean(opimgo6)
    opimgo6=opimgo6-muo6
                
        
    xo6, binso6, po6=plt.hist(opimgo6, 256, density=True)
    xo6=xo6+epsilon
    objo6.append(xo6)

objo6=np.array(objo6)
print(len(bboxo6))
# Out:
# 2

# %%
Patho7 = './Downloads/Original_IETR/Newspaper_cam04_56_original.png'

tempo7 = cv2.imread(Patho7)

objo7=[]

bboxo7, labelo7, confo7= cv.detect_common_objects(tempo7)

output_imageo7 = draw_bbox(tempo7, bboxo7, labelo7, confo7)


for o in range (len(bboxo7)):
    
    
    opimgo7=output_imageo7[bboxo7[o][1]:bboxo7[o][3],bboxo7[o][0]:bboxo7[o][2]].flatten()
    muo7=np.mean(opimgo7)
    opimgo7=opimgo7-muo7
                
        
    xo7, binso7, po7=plt.hist(opimgo7, 256, density=True)
    xo7=xo7+epsilon
    objo7.append(xo7)

objo7=np.array(objo7)
print(len(bboxo7))
# Out:
# 10

# %%
Patho8 = './Downloads/Original_IETR/PoznanHall2_cam06_150_original.png'

tempo8 = cv2.imread(Patho8)

objo8=[]

bboxo8, labelo8, confo8= cv.detect_common_objects(tempo8)

output_imageo8 = draw_bbox(tempo8, bboxo8, labelo8, confo8)


for p in range (len(bboxo8)):
    
    
    opimgo8=output_imageo8[bboxo8[p][1]:bboxo8[p][3],bboxo8[p][0]:bboxo8[p][2]].flatten()
    muo8=np.mean(opimgo8)
    opimgo8=opimgo8-muo8
                
        
    xo8, binso8, po8=plt.hist(opimgo8, 256, density=True)
    xo8=xo8+epsilon
    objo8.append(xo8)

objo8=np.array(objo8)
print(len(bboxo8))
# Out:
# 3

# %%
Patho9 = './Downloads/Original_IETR/Poznan_Street_cam04_26_original.png'

tempo9 = cv2.imread(Patho9)

objo9=[]

bboxo9, labelo9, confo9= cv.detect_common_objects(tempo9)

output_imageo9 = draw_bbox(tempo9, bboxo9, labelo9, confo9)


for q in range (len(bboxo9)):
    
    
    opimgo9=output_imageo9[bboxo9[q][1]:bboxo9[q][3],bboxo9[q][0]:bboxo9[q][2]].flatten()
    muo9=np.mean(opimgo9)
    opimgo9=opimgo9-muo9
                
        
    xo9, binso9, po9=plt.hist(opimgo9, 256, density=True)
    xo9=xo9+epsilon
    objo9.append(xo9)

objo9=np.array(objo9)
print(objo9[1])
# Out:
# [2.70235737e-04 3.73582726e-05 6.59187164e-05 6.37217592e-05
#  1.64781791e-04 2.94402267e-04 6.85460651e-04 8.61217228e-04
#  1.87621146e-03 2.52870775e-03 2.86703916e-03 3.27567321e-03
#  3.58983809e-03 4.05778997e-03 3.44703587e-03 4.40710617e-03
#  4.08635042e-03 4.59824145e-03 4.92998199e-03 4.10831999e-03
#  4.68831670e-03 4.34778833e-03 4.25112221e-03 1.10616896e-02
#  3.59862592e-03 4.30604614e-03 3.46241457e-03 4.00506300e-03
#  3.77877641e-03 3.41627847e-03 3.82930642e-03 3.58544417e-03
#  4.12589565e-03 3.56786852e-03 4.13468348e-03 3.77657945e-03
#  4.04680519e-03 3.38332411e-03 3.76779162e-03 4.34339441e-03
#  3.96112386e-03 4.31483397e-03 4.21377394e-03 4.61362015e-03
#  4.27748570e-03 4.78498281e-03 4.85528544e-03 4.92119416e-03
#  5.43967606e-03 5.19801077e-03 5.39793388e-03 5.08816291e-03
#  5.89224925e-03 5.51217565e-03 5.43967606e-03 5.16725337e-03
#  5.25293470e-03 5.27490427e-03 4.69710452e-03 5.88346142e-03
# ...

# %%
Patho10 = './Downloads/Original_IETR/Shark_cam05_220_original.png'

tempo10 = cv2.imread(Patho10)

objo10=[]

bboxo10, labelo10, confo10= cv.detect_common_objects(tempo10)

output_imageo10 = draw_bbox(tempo10, bboxo10, labelo10, confo10)


for r in range (len(bboxo10)):
    
    
    opimgo10=output_imageo10[bboxo10[r][1]:bboxo10[r][3],bboxo10[r][0]:bboxo10[r][2]].flatten()
    muo10=np.mean(opimgo10)
    opimgo10=opimgo10-muo10
                
        
    xo10, binso10, po10=plt.hist(opimgo10, 256, density=True)
    xo10=xo10+epsilon
    objo10.append(xo10)

objo9=np.array(objo10)
print(len(bboxo10))
# Out:
# 2

# %%
Pathd1 = './Downloads/D1/'
filesd1 = os.listdir(Pathd1)
objd1 = []

#Readling all the images and storing into an array
for named1 in filesd1:
    tempd1 = cv2.imread(Pathd1+named1)
    imgd1=tempd1[bboxo1[0][1]:bboxo1[0][3],bboxo1[0][0]:bboxo1[0][2]].flatten()
    mud1=np.mean(imgd1)
    imgd1=imgd1-mud1
        
    xd1,bind1,pd1=plt.hist(imgd1,256,density=True)
    xd1=xd1+epsilon
    objd1.append(KL(pdfo1,xd1))
        
print(objd1)
# Out:
# [8.837719283483537, 10.546050595372616, 16.484113815774794, 11.45007896767185, 15.355707899204502, 16.401635523842266, 18.78451153721568, 19.711104966843166, 12.16869979301515, 10.386194129620657, 10.037824895288969, 12.082028809047914, 9.46366969497549, 10.909515796839596]

# %%
Pathd2 = './Downloads/D2/'
filesd2 = os.listdir(Pathd2)
objd2 = []

#Readling all the images and storing into an array
for named2 in filesd2:
    tempd2 = cv2.imread(Pathd2+named2)
      
    
    #1
    imgd21=tempd2[bboxo2[0][1]:bboxo2[0][3],bboxo2[0][0]:bboxo2[0][2]].flatten()
    mud21=np.mean(imgd21)
    imgd21=imgd21-mud21
        
    xd21,bind21,pd21=plt.hist(imgd21,256,density=True)
    xd21=xd21+epsilon
    
    #2
    imgd22=tempd2[bboxo2[1][1]:bboxo2[1][3],bboxo2[1][0]:bboxo2[1][2]].flatten()
    mud22=np.mean(imgd22)
    imgd22=imgd22-mud22
        
    xd22,bind22,pd22=plt.hist(imgd22,256,density=True)
    xd22=xd22+epsilon
    
    #3
    imgd23=tempd2[bboxo2[2][1]:bboxo2[2][3],bboxo2[2][0]:bboxo2[2][2]].flatten()
    mud23=np.mean(imgd23)
    imgd23=imgd23-mud23
        
    xd23,bind23,pd23=plt.hist(imgd23,256,density=True)
    xd23=xd23+epsilon
    
    #4
    imgd24=tempd2[bboxo2[3][1]:bboxo2[3][3],bboxo2[3][0]:bboxo2[3][2]].flatten()
    mud24=np.mean(imgd24)
    imgd24=imgd24-mud24
        
    xd24,bind24,pd24=plt.hist(imgd24,256,density=True)
    xd24=xd24+epsilon
    
    #5
    imgd25=tempd2[bboxo2[4][1]:bboxo2[4][3],bboxo2[4][0]:bboxo2[4][2]].flatten()
    mud25=np.mean(imgd25)
    imgd25=imgd25-mud25
        
    xd25,bind25,pd25=plt.hist(imgd25,256,density=True)
    xd25=xd25+epsilon
    
    #6
    imgd26=tempd2[bboxo2[5][1]:bboxo2[5][3],bboxo2[5][0]:bboxo2[5][2]].flatten()
    mud26=np.mean(imgd26)
    imgd26=imgd26-mud26
        
    xd26,bind26,pd26=plt.hist(imgd26,256,density=True)
    xd26=xd26+epsilon
    
    objd2.append(KL(objo2[0],xd21)+KL(objo2[1],xd22)+KL(objo2[2],xd23)+KL(objo2[3],xd24)+KL(objo2[4],xd25)+KL(objo2[5],xd26))
# Out:
# (169647,)

# %%
Pathd3 = './Downloads/D3/'
filesd3 = os.listdir(Pathd3)
objd3 = []

#Readling all the images and storing into an array
for named3 in filesd3:
    tempd3 = cv2.imread(Pathd3+named3)
    imgd3=tempd3[bboxo3[0][1]:bboxo3[0][3],bboxo3[0][0]:bboxo3[0][2]].flatten()
    mud3=np.mean(imgd3)
    imgd3=imgd3-mud3
        
    xd3,bind3,pd3=plt.hist(imgd3,256,density=True)
    xd3=xd3+epsilon
    objd3.append(KL(xo3,xd3))
        
print(objd3)
# Out:
# [7.701321778093696, 7.71291513939185, 7.687274248788358, 7.689487125494406, 7.686953032518386, 7.767853728437696, 7.714968492589149, 7.713061455770921, 7.687772991304753, 7.688044790719076, 7.687561395438607, 7.766863907696006, 7.717043814086296, 7.709918694158892]

# %%
Pathd4 = './Downloads/D4/'
filesd4 = os.listdir(Pathd4)
objd4 = []
xxd41=[]

#Readling all the images and storing into an array
for named4 in filesd4:
    tempd4 = cv2.imread(Pathd4+named4)
      
    
    #1
    imgd41=tempd4[bboxo4[0][1]:bboxo4[0][3],bboxo4[0][0]:bboxo4[0][2]].flatten()
    mud41=np.mean(imgd41)
    imgd41=imgd41-mud41
    
        
    xd41,bind41,pd41=plt.hist(imgd41,256,density=True)
    xd41=xd41+epsilon
    #xxd41.append(xd41)
    
    #2
    imgd42=tempd4[bboxo4[1][1]:bboxo4[1][3],bboxo4[1][0]:bboxo4[1][2]].flatten()
    mud42=np.mean(imgd42)
    imgd22=imgd22-mud22
        
    xd42,bind42,pd42=plt.hist(imgd42,256,density=True)
    xd42=xd42+epsilon
    
    objd4.append(KL(objo4[0],xd41)+KL(objo4[1],xd42))
print(objd4)
# Out:
# [24.774497726272756, 24.697342688502626, 24.85240706011534, 24.86319241009469, 24.834223398047037, 24.42009552580829, 25.27679037269921, 25.09306384558106, 24.870022928940397, 24.905164082481107, 24.873096657953255, 24.82603848998894, 24.892067348667652, 25.00041717459131]

# %%
Pathd5 = './Downloads/D5/'
filesd5 = os.listdir(Pathd5)
objd5 = []

#Readling all the images and storing into an array
for named5 in filesd5:
    tempd5 = cv2.imread(Pathd5+named5)
      
    
    #1
    imgd51=tempd5[bboxo5[0][1]:bboxo5[0][3],bboxo5[0][0]:bboxo5[0][2]].flatten()
    mud51=np.mean(imgd51)
    imgd51=imgd51-mud51
        
    xd51,bind51,pd51=plt.hist(imgd51,256,density=True)
    xd51=xd51+epsilon
    
    #2
    imgd52=tempd5[bboxo5[1][1]:bboxo5[1][3],bboxo5[1][0]:bboxo5[1][2]].flatten()
    mud52=np.mean(imgd52)
    imgd52=imgd52-mud52
        
    xd52,bind52,pd52=plt.hist(imgd52,256,density=True)
    xd52=xd52+epsilon
    
    #3
    imgd53=tempd5[bboxo5[2][1]:bboxo5[2][3],bboxo5[2][0]:bboxo5[2][2]].flatten()
    mud53=np.mean(imgd53)
    imgd53=imgd53-mud53
        
    xd53,bind53,pd53=plt.hist(imgd53,256,density=True)
    xd53=xd53+epsilon
    
    #4
    imgd54=tempd5[bboxo5[3][1]:bboxo5[3][3],bboxo5[3][0]:bboxo5[3][2]].flatten()
    mud54=np.mean(imgd54)
    imgd54=imgd54-mud54
        
    xd54,bind54,pd54=plt.hist(imgd54,256,density=True)
    xd54=xd54+epsilon
    
    #5
    imgd55=tempd5[bboxo5[4][1]:bboxo5[4][3],bboxo5[4][0]:bboxo5[4][2]].flatten()
    mud55=np.mean(imgd55)
    imgd55=imgd55-mud55
        
    xd55,bind55,pd55=plt.hist(imgd55,256,density=True)
    xd55=xd55+epsilon
    
    #6
    imgd56=tempd5[bboxo5[5][1]:bboxo5[5][3],bboxo5[5][0]:bboxo5[5][2]].flatten()
    mud56=np.mean(imgd56)
    imgd56=imgd56-mud56
        
    xd56,bind56,pd56=plt.hist(imgd56,256,density=True)
    xd56=xd56+epsilon
    
    #7
    imgd57=tempd5[bboxo5[6][1]:bboxo5[6][3],bboxo5[6][0]:bboxo5[6][2]].flatten()
    mud57=np.mean(imgd57)
    imgd57=imgd57-mud57
        
    xd57,bind57,pd57=plt.hist(imgd57,256,density=True)
    xd57=xd57+epsilon
    
    objd5.append(KL(objo5[0],xd51)+KL(objo5[1],xd52)+KL(objo5[2],xd53)+KL(objo5[3],xd54)+KL(objo5[4],xd55)+KL(objo5[5],xd56)+KL(objo5[6],xd57))
    

print(objd5)
# Out:
# [51.527056218031674, 51.64464288676083, 51.16674187079496, 50.67638673650376, 51.595315624484655, 52.07191636983961, 52.16728826964172, 52.0639034144003, 51.32142880379321, 51.30919480870581, 51.30393063747283, 51.93981254539851, 51.3699654757956, 51.45630172236049]

# %%
Pathd6 = './Downloads/D6/'
filesd6 = os.listdir(Pathd6)
objd6 = []
xxd61=[]

#Readling all the images and storing into an array
for named6 in filesd6:
    tempd6 = cv2.imread(Pathd6+named6)
      
    
    #1
    imgd61=tempd6[bboxo6[0][1]:bboxo6[0][3],bboxo6[0][0]:bboxo6[0][2]].flatten()
    mud61=np.mean(imgd61)
    imgd61=imgd61-mud61
    
        
    xd61,bind61,pd61=plt.hist(imgd61,256,density=True)
    xd61=xd61+epsilon
    #xxd61.append(xd61)
    
    #2
    imgd62=tempd6[bboxo6[1][1]:bboxo6[1][3],bboxo6[1][0]:bboxo6[1][2]].flatten()
    mud62=np.mean(imgd62)
    imgd62=imgd62-mud62
        
    xd62,bind62,pd62=plt.hist(imgd42,256,density=True)
    xd62=xd62+epsilon
    
    objd6.append(KL(objo6[0],xd61)+KL(objo6[1],xd62))
print(objd6)
# Out:
# [20.50716856036781, 20.511362510713383, 20.501301791814953, 20.555529937625245, 20.503952304766116, 20.497827902574716, 20.50432365374941, 20.45409628276777, 20.46541698537028, 20.46912513085092, 20.465330588223484, 20.508905396548087, 20.469866018469993, 20.44759424643763]

# %%
Pathd7 = './Downloads/D7/'
filesd7 = os.listdir(Pathd7)
objd7 = []

#Readling all the images and storing into an array
for named7 in filesd7:
    tempd7 = cv2.imread(Pathd7+named7)
      
    
    #1
    imgd71=tempd7[bboxo7[0][1]:bboxo7[0][3],bboxo7[0][0]:bboxo7[0][2]].flatten()
    mud71=np.mean(imgd71)
    imgd71=imgd71-mud71
        
    xd71,bind71,pd71=plt.hist(imgd71,256,density=True)
    xd71=xd71+epsilon
    
    #2
    imgd72=tempd7[bboxo7[1][1]:bboxo7[1][3],bboxo7[1][0]:bboxo7[1][2]].flatten()
    mud72=np.mean(imgd72)
    imgd72=imgd72-mud72
        
    xd72,bind72,pd72=plt.hist(imgd72,256,density=True)
    xd72=xd72+epsilon
    
    #3
    imgd73=tempd7[bboxo7[2][1]:bboxo7[2][3],bboxo7[2][0]:bboxo7[2][2]].flatten()
    mud73=np.mean(imgd73)
    imgd73=imgd73-mud73
        
    xd73,bind73,pd73=plt.hist(imgd73,256,density=True)
    xd73=xd73+epsilon
    
    #4
    imgd74=tempd7[bboxo7[3][1]:bboxo7[3][3],bboxo7[3][0]:bboxo7[3][2]].flatten()
    mud74=np.mean(imgd74)
    imgd74=imgd74-mud74
        
    xd74,bind74,pd74=plt.hist(imgd74,256,density=True)
    xd74=xd74+epsilon
    
    #5
    imgd75=tempd7[bboxo7[4][1]:bboxo7[4][3],bboxo7[4][0]:bboxo7[4][2]].flatten()
    mud75=np.mean(imgd75)
    imgd75=imgd75-mud75
        
    xd75,bind75,pd75=plt.hist(imgd75,256,density=True)
    xd75=xd75+epsilon
    
    #6
    imgd76=tempd7[bboxo7[5][1]:bboxo7[5][3],bboxo7[5][0]:bboxo7[5][2]].flatten()
    mud76=np.mean(imgd76)
    imgd76=imgd76-mud76
        
    xd76,bind76,pd76=plt.hist(imgd76,256,density=True)
    xd76=xd76+epsilon
    
    #7
    imgd77=tempd7[bboxo7[6][1]:bboxo7[6][3],bboxo7[6][0]:bboxo7[6][2]].flatten()
    mud77=np.mean(imgd77)
    imgd77=imgd77-mud77
        
    xd77,bind77,pd77=plt.hist(imgd77,256,density=True)
    xd77=xd77+epsilon
    
    
    #8
    imgd78=tempd7[bboxo7[7][1]:bboxo7[7][3],bboxo7[7][0]:bboxo7[7][2]].flatten()
    mud78=np.mean(imgd78)
    imgd78=imgd78-mud78
        
    xd78,bind78,pd78=plt.hist(imgd78,256,density=True)
    xd78=xd78+epsilon
    
    #9
    imgd79=tempd7[bboxo7[8][1]:bboxo7[8][3],bboxo7[8][0]:bboxo7[8][2]].flatten()
    mud79=np.mean(imgd79)
    imgd79=imgd79-mud79
        
    xd79,bind79,pd79=plt.hist(imgd79,256,density=True)
    xd79=xd79+epsilon
    
    #10
    imgd710=tempd7[bboxo7[9][1]:bboxo7[9][3],bboxo7[9][0]:bboxo7[9][2]].flatten()
    mud710=np.mean(imgd710)
    imgd710=imgd710-mud710
        
    xd710,bind710,pd710=plt.hist(imgd710,256,density=True)
    xd710=xd710+epsilon
    
    
    objd7.append(KL(objo7[0],xd71)+KL(objo7[1],xd72)+KL(objo7[2],xd73)+KL(objo7[3],xd74)+KL(objo7[4],xd75)+KL(objo7[5],xd76)+KL(objo7[6],xd77)+KL(objo7[7],xd78)+KL(objo7[8],xd79)+KL(objo7[9],xd710))
    

print(objd7)
# Out:
# [87.7825459390093, 87.62544886957352, 86.68579070322768, 88.9632747875136, 86.03662619632223, 84.76766228214265, 89.48683811271565, 85.43627733770137, 88.50217034150639, 88.41404273608435, 87.78443900753226, 84.63812510386423, 86.38725791251993, 87.8162895166823]

# %%
Pathd8 = './Downloads/D8/'
filesd8 = os.listdir(Pathd8)
objd8 = []


#Readling all the images and storing into an array
for named8 in filesd8:
    tempd8 = cv2.imread(Pathd8+named8)
      
    
    #1
    imgd81=tempd8[bboxo8[0][1]:bboxo8[0][3],bboxo8[0][0]:bboxo8[0][2]].flatten()
    mud81=np.mean(imgd81)
    imgd81=imgd81-mud81
    
        
    xd81,bind81,pd81=plt.hist(imgd81,256,density=True)
    xd81=xd81+epsilon
    #xxd61.append(xd61)
    
    #2
    imgd82=tempd8[bboxo8[1][1]:bboxo8[1][3],bboxo8[1][0]:bboxo8[1][2]].flatten()
    mud82=np.mean(imgd82)
    imgd82=imgd82-mud82
        
    xd82,bind82,pd82=plt.hist(imgd82,256,density=True)
    xd82=xd82+epsilon
    
    
    #3
    imgd83=tempd8[bboxo8[2][1]:bboxo8[2][3],bboxo8[2][0]:bboxo8[2][2]].flatten()
    mud83=np.mean(imgd83)
    imgd83=imgd83-mud83
        
    xd83,bind83,pd83=plt.hist(imgd83,256,density=True)
    xd83=xd83+epsilon
    
    
    
    objd8.append(KL(objo8[0],xd81)+KL(objo8[1],xd82)+KL(objo8[2],xd83))
print(objd8)
# Out:
# [73.23490990392776, 69.62876240777588, 64.05066262078212, 64.04785403822521, 64.0996651997858, 64.48685213718721, 64.09997931030398, 64.74367994761383, 64.87202591109691, 68.74850262016935, 68.63702816637196, 68.58511719313313, 70.58730855661659, 67.5325001679373]

# %%
Pathd9 = './Downloads/D9/'
filesd9 = os.listdir(Pathd9)
objd9 = []


#Readling all the images and storing into an array
for named9 in filesd9:
    tempd9 = cv2.imread(Pathd9+named9)
      
    
    #1
    imgd91=tempd9[bboxo9[0][1]:bboxo9[0][3],bboxo9[0][0]:bboxo9[0][2]].flatten()
    mud91=np.mean(imgd91)
    imgd91=imgd91-mud91
    
        
    xd91,bind91,pd91=plt.hist(imgd91,256,density=True)
    xd91=xd91+epsilon
    #xxd61.append(xd61)
    
    #2
    imgd92=tempd9[bboxo9[1][1]:bboxo9[1][3],bboxo9[1][0]:bboxo9[1][2]].flatten()
    mud92=np.mean(imgd92)
    imgd92=imgd92-mud92
        
    xd92,bind92,pd92=plt.hist(imgd92,256,density=True)
    xd92=xd92+epsilon
    
    
    #3
    imgd93=tempd9[bboxo9[2][1]:bboxo9[2][3],bboxo9[2][0]:bboxo9[2][2]].flatten()
    mud93=np.mean(imgd93)
    imgd93=imgd93-mud93
        
    xd93,bind93,pd93=plt.hist(imgd93,256,density=True)
    xd93=xd93+epsilon
    
    
    #4
    imgd94=tempd9[bboxo9[3][1]:bboxo9[3][3],bboxo9[3][0]:bboxo9[3][2]].flatten()
    mud94=np.mean(imgd94)
    imgd94=imgd94-mud94
        
    xd94,bind94,pd94=plt.hist(imgd94,256,density=True)
    xd94=xd94+epsilon
    
    
    objd9.append(KL(objo9[0],xd91)+KL(objo9[1],xd92)+KL(objo9[2],xd93)+KL(objo9[3],xd94))
    
print(objd9)
# Out:
# [30.342483970531298, 30.712964229137626, 30.701393149870967, 30.704456541699187, 30.702568826470575, 30.577177971266018, 30.716674886357602, 30.7954247697374, 30.24705050813182, 30.243946709937102, 30.27938110961366, 30.65021099844762, 30.432714573953547, 30.42618126429958]

# %%
Pathd10 = './Downloads/D10/'
filesd10 = os.listdir(Pathd10)
objd10 = []


#Readling all the images and storing into an array
for named10 in filesd10:
    tempd10 = cv2.imread(Pathd10+named10)
      
    
    #1
    imgd101=tempd10[bboxo10[0][1]:bboxo10[0][3],bboxo10[0][0]:bboxo10[0][2]].flatten()
    mud101=np.mean(imgd101)
    imgd101=imgd101-mud101
    
        
    xd101,bind101,pd101=plt.hist(imgd101,256,density=True)
    xd101=xd101+epsilon
    #xxd61.append(xd61)
    
    #2
    imgd102=tempd10[bboxo10[1][1]:bboxo10[1][3],bboxo10[1][0]:bboxo10[1][2]].flatten()
    mud102=np.mean(imgd102)
    imgd102=imgd102-mud102
        
    xd102,bind102,pd102=plt.hist(imgd102,256,density=True)
    xd102=xd102+epsilon
    
    objd10.append(KL(objo10[0],xd101)+KL(objo10[1],xd102))
print(objd10)
# Out:
# [22.552848913046503, 23.12142556514059, 21.76299508845713, 21.76175261048264, 21.731866678736743, 21.87108613246532, 22.234240513883293, 22.881775186282727, 22.537328364652968, 22.529080044868167, 21.19412848964785, 22.651202742350375, 23.842342193797137, 23.942361028310895]

# %%
kld_syn=[]
kld_real=[]

kld_syn.append(objd3)
kld_syn.append(objd4)
kld_syn.append(objd10)

kld_real.append(objd1)
kld_real.append(objd2)
kld_real.append(objd5)
kld_real.append(objd6)
kld_real.append(objd7)
kld_real.append(objd8)
kld_real.append(objd9)

kld_real=np.array(kld_real)
kld_syn=np.array(kld_syn)
print(kld_syn.shape)
# Out:
# (3, 14)

# %%
obj_score_real=(kld_real.flatten())
obj_score_syn=(kld_syn.flatten())

# %%
#Subjective scores of original images
new_sub_orig=np.array([0.591450046206532,
0.662523941863571,
0.482770611989651,
0.784196184203399,
0.282522277106338,
0.647464473052446,
0.305047110033448,
0.29277954439822,
0.489600552640186,
0.497514516912261,
0.499754554978394,
0.826163743067733,
0.162313593846142,
0.452732703190989,
0.240174830416431,
0.173654841694507,
0.530078954891447,
0.837074523344541,
0.478473785829511,
0.833064726381777,
0.369448429070808,
0.686376045932332,
0.560928889708332,
0.819290713651848,
0.416449954740804,
0.66758800796767,
0.149527360137351,
0.435486201211814,
0.032865927003549,
0.167095821472421,
0.633511207418824,
0.58086832685444,
0.498674311251136,
0.90645743512307,
0.389031972482008,
0.406285009058487,
0.595752358048127,
0.51135819227138,
0.518993287064144,
0.924073630989853,
0.330146860323064,
0.439550081679502,
0.282999409333829,
0.201693696265621,
0.775300901852862,
0.647753354344015,
0.551428333644776,
0.777188452399451,
0.367546271185079,
0.624584748177781,
0.754365815714084,
0.785579080784981,
0.77966129542017,
0.669638401087394,
0.133265501709099,
0.657534869077368,
0.090079728400751,
0.219564569389693,
0.583889735265927,
0.716360444074853,
0.594113188456475,
0.728014429567815,
0.107997663227676,
0.678428567551548,
0.710816964350032,
0.943633121341149,
0.705653821098252,
0.619209641653573,
0.264531428485334,
0.753319937363287,
0.036670518094472,
0.13962757767007,
0.745884386453196,
0.526282428013834,
0.660350709447516,
0.863305906634233,
0.2967184073528,
0.27047354346028,
0.719367700726814,
0.715783896474824,
0.590785267234655,
0.993188588327144,
0.499050685111133,
0.392189069256821,
0.047356890366184,
0.16789800389884,
0.628484045879569,
0.712783798798584,
0.723456269376853,
0.837042232299577,
0.255287851409832,
0.303467677517448,
0.690995710536917,
0.786814526447799,
0.734118125343431,
0.822787013990674,
0.280087692964191,
0.227792912603308
])

#sunjective scores of synthetic images

new_sub_syn=np.array([0.679082366068258,
0.529551830265255,
0.672434449272598,
0.848435869440699,
0.239381573498838,
0.519363875165456,
0.098485509875757,
0.250368894907729,
0.774666840849666,
0.580021871381838,
0.682754501970252,
0.964006325086385,
0.432258795632313,
0.517068804044989,
0.863510062111633,
0.908324011242464,
0.738170293104672,
0.866538453029475,
0.81877185003214,
0.838498549081274,
0.036201738640763,
0.350598252172135,
0.619883844248706,
0.715318324601426,
0.673017796296823,
0.651627664348734,
0.505453784615257,
0.61210770043521,
0.02104915158573,
0.149706508121121,
0.693170061835007,
0.603005180641202,
0.581354154027684,
0.907311845453262,
0.206689847152443,
0.303516481939392,
0.714746037750429, 
0.628444329467981,
0.555000504270454,
0.9609795663716,
0.119566755981298,
0.275728490210608])

# %%
corr_orig=scipy.stats.spearmanr(new_sub_orig,obj_score_real)
corr_syn=scipy.stats.spearmanr(new_sub_syn,obj_score_syn)

# %%
#final correlation coeff.
final=np.power(np.abs(corr_orig[0]),0.7)+np.power(np.abs(corr_syn[0]),0.3)

# %%
print(final)
# Out:
# 0.44335437415055223

# %%
cp=scipy.stats.pearsonr(new_sub_orig,obj_score_real)
cp1=scipy.stats.pearsonr(new_sub_syn,obj_score_syn)
finalx=np.power(np.abs(cp[0]),0.7)+np.power(np.abs(cp1[0]),0.3)
print(finalx)
# Out:
# 0.38238118008620625

# %%
vec=np.array([0.72,0.44])

x=np.sum(vec)

vecx=vec/x

print(vecx)
# Out:
# [0.62068966 0.37931034]

# %%
yx=vecx[0]*(np.power(vec[0],vecx[0]))+vecx[1]*(np.power(vec[1],vecx[1]))

# %%
#mix corr coeff. for yolo network and global pdf based algorithm
print(yx)
# Out:
# 0.7840131653453725

# %%
from PIL import Image

# %%
print(x.shape)
# Out:
# (140, 28, 28)
